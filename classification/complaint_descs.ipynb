# %%
import pandas as pd

# %%
def read_dfs():
    dfa = pd.read_csv("../data/fuse/com_abbeville_pd.csv")
    dfa = dfa[["allegation_desc", "tracking_id_og"]]
    dfb = pd.read_csv("../data/fuse/com_baton_rouge_pd.csv")
    dfb = dfb[["allegation_desc", "tracking_id_og"]]
    dfc = pd.read_csv("../data/fuse/com_benton_pd.csv")
    dfc = dfc[["allegation_desc"]]
    dfd = pd.read_csv("../data/fuse/com_bossier_city_pd.csv")
    dfd = dfd[["allegation_desc", "tracking_id_og"]]
    dfe = pd.read_csv("../data/fuse/com_denham_springs_pd.csv")
    dfe = dfe[["allegation_desc", "tracking_id_og"]]
    dff = pd.read_csv("../data/fuse/com_new_orleans_so.csv")
    dff = dff[["allegation_desc", "tracking_id_og"]]
    dfg = pd.read_csv("../data/fuse/com_rayne_pd.csv")
    dfg = dfg[["allegation_desc"]]
    dfh = pd.read_csv("../data/clean/cprr_new_orleans_pd_pib_reports_2014_2020.csv")
    dfh = dfh[["allegation_desc", "tracking_id_og"]]

    dfs = [dfa, dfb, dfc, dfd, dfe, dff, dfg, dfh]
    df = pd.concat(dfs, axis=0)
    return df

# %%
df = read_dfs()

# %%
df = df.rename(columns={"tracking_id_og": "meta",})
df = df[~((df.allegation_desc.fillna("") == ""))]
df = df.drop_duplicates(subset=["allegation_desc"])

# %%
df["label"] = ""

df["target"] = ""

df = df.astype(str)
df.loc[df.index[:2000], 'target'] = 1
df.loc[df.index[2000:2500], 'target'] = 0

df.iloc[900:950]
# Out:
#                                         allegation_desc      meta label target
# 1606              failed to notify rank of her absence.  B-022-20            0
# 1608  accused of not maintaining a professional deme...  f-032-21            0
# 1611  accused of ignoring her ranks orders to assist...  b-012-21            0
# 1613         refused an assignment "inmate head count "  d-038-21            0
# 1616  accused of being in a veral/physical altercati...  k-022-21            0
# 1627  failed to complete his dailey unit security lo...  K-013-20            0
# 1631  accused of leaving work prior to the end of hi...  L-009-19            0
# 1634     failed to effect his duties a ranking officer.  H-002-19            0
# 1637  acued of not allowing inmates to pray in mulie...  E-023-19            0
# 1638  accused of not taking the necessary actions to...  c-013-21            0
# 1640  accused of dicussing an incident which occurre...  F-001-19            0
# 1645            observed with lumber hanging from unit.  E-013-20            0
# 1646  failed to complete a hand written statement fo...  c-015-21            0
# 1648    accused of talking loudly to a ranking officer.  i-025-21            0
# 1650                             reportedlate for duty.  j-049-21            0
# 1652     conducted himself in an unprofessional manner.  E-006-20            0
# 1655      involved in accident a failed to notify rank.  F-002-20            0
# 1659  found to have acted in a manner unbecoming of ...  J-007-19            1
# 1663  accused of not calling the pods to get the off...  j-046-21            0
# 1664  accused of having inmates without leg shakles ...  e-001-21            0
# 1665  refused to returned opso bwc magnetics backs t...  k-015-21            0
# 1667  accused of working unauthorized overtine on 2/...  c-014-21            0
# 1668  failed to inventory and at the at the beginnin...  j-032-21            0
# 1669   engaged in averbal altercation with subordinate.  c-018-21            0
# 1671  accused of excessive on an inmate failed to co...  i-016-21            0
# 1672  accused of being discourteous towards her supe...  e-042-21            0
# 1674  failed to report to duty on friday, september ...  j-007-21            0
# 1675     left her pod for lunch and returned two later.  J-008-19            0
# 1676  deputy mercadel was not in complete uniform. \...  L-005-20            0
# 1677  accused of not completing his 24 rounds/inspec...  e-041-21            0
# 1682  accused of not making sure that the deputies c...  f-016-21            0
# 1683                       admitted to using marijuana.  d-014-21            0
# 1687  refused to call the pods to get inmates head c...  k-001-21            0
# 1691  failed to activate his body worn camera during...  c-041-21            0
# 1695  failed to properly interven between subordinat...  k-005-21            0
# 1703       failed to provide weekly statistics for ipc.  e-099-21            1
# 1705   refused an assignment clocked out and went home.  e-083-21            0
# 1706               accpeted phone calls from an inmate.  J-006-19            0
# 1707  failed to complete a transfer sheet upon compl...  L-035-19            0
# 1708             observed with hair below shirt collar.  C-026-20            0
# 1711          allowed inmates to be in incorrect cells.  H-016-19            0
# 1717                 accused of refusing an assignment.  G-055-19            0
# 1719  failed to follow instruction from her supervis...  L-028-20            1
# 1720               was observed sleeping while on duty.  b-030-21            0
# 1721            failed to arrive on time for roll call.  E-020-20            0
# 1722                       unauthorized use of movable.  D-001-19            0
# 1724  forcibly pushing inmate kenshawn king inside h...  g-018-21            0
# 1725  failed to complete uof report within 36 hours ...  c-032-21            0
# 1727  allowed inmates to horseplay while playing in ...  I-015-19            0
# 1728  observed on two ocassions with hair pass shoul...  A-039-19            0

# %%
df.to_csv("../data/training_data/allegation_desc.csv", index=False)
