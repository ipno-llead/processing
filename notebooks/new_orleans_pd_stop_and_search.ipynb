# %%
import sys; sys.path.append('../')

import pandas as pd

import dirk
from lib.explore import  show_columns_with_differences
from clean.new_orleans_pd_stop_and_search import clean

# %%
df = clean()
df
# Out:
# /Users/khoipham/.virtualenvs/base/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (16,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# standardize_from_lookup_table: unmatched sequences:
#   {'364381', 'unknown'}
#         stop_and_search_interview_id item_number  district zone  \
# 0                              17415         NaN         6    e
# 1                              17416         NaN         5    d
# 2                              17416         NaN         5    d
# 3                              17416         NaN         5    d
# 4                              17416         NaN         5    d
# ...                              ...         ...       ...  ...
# 830876                        547134    L3697820         6    q
# 830877                        547135    L3698220         8    a
# ...

# %%
dups = df.loc[df.stop_and_search_uid.duplicated(keep=False)].sort_values('stop_and_search_uid')
dups
# Out:
#         stop_and_search_interview_id item_number  district zone  \
# 180163                        156605    C3634812         7    c
# 180164                        156605    C3634812         7    c
# 409292                        103773    F4098111         7    o
# 409291                        103773    F4098111         7    o
# 347647                         29962         NaN         2    j
# ...                              ...         ...       ...  ...
# 235756                        239521    D2048814         1    c
# 250441                        297296    D2739315         4    i
# 250440                        297296    D2739315         4    i
# 90524                         345282    B1155716         3    i
# 90523                         345282    B1155716         3    i
#
#               stop_reason vehicle_year vehicle_make vehicle_model  \
# 180163  traffic violation         2008    chevrolet     silverado
# ...

# %%
show_columns_with_differences(dups[dups.stop_and_search_uid == '1c3b6d6b26081104a791f6c511a80711'])
# Out:
#        badge_number
# 409292          637
# 409291          874
