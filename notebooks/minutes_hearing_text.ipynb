# %%
import sys; sys.path.insert(0, "..")
import pandas as pd
import deba
deba.set_root("..")

from features.minutes_hearing_text import extract_hearing_text

# %%
df = extract_hearing_text()
df
# Out:
#         docid            region  hrg_no  \
# 0    055576a1            kenner     0.0
# 1    055576a1            kenner     1.0
# 2    05d91c70            kenner     0.0
# 3    0656dbae            kenner     0.0
# 4    07680203            kenner     0.0
# ..        ...               ...     ...
# 252  f97175cb            kenner     1.0
# 253  fa5999ae            kenner     0.0
# 254  fa5999ae            kenner     1.0
# 255  ffb6a366  east_baton_rouge     0.0
# 256  ffb6a366  east_baton_rouge     1.0
#
#                                               hrg_text  start_pageno  \
# 0    AGENDA ITEM #3\nDISCUSSION: GRANT HEARING OF A...            20
# 1    AGENDA ITEM #8\nDISCUSSION: CERTIFY TRANSCRIPT...            23
# 2    AGENDA ITEM #4\nHEARING OF APPEAL\nFIRE DRIVER...            20
# 3    AGENDA ITEM #3\nHEARING OF APPEAL: POLICE OFFI...             1
# 4    AGENDA ITEM #4\nDISCUSSION: GRANT HEARING OF A...            15
# ..                                                 ...           ...
# 252  AGENDA ITEM #4\nHEARING: LIEUTENANT RICHARD MO...             3
# 253  AGENDA ITEM #3\nHEARING OF APPEAL: Correctiona...             9
# 254  AGENDA ITEM #5\nDISCUSSION: GRANT HEARING OF A...            10
# 255  APPEAL HEARING FOR LORINE WILLIAMS (1 DAY SUSP...            16
# 256  APPEAL HEARING FOR TEDDY TORRES (3 DAY SUSPENS...            16
#
#      end_pageno parsed_date          accused  \
# 0            21  2007-02-05   daniel vitrano
# 1            23         NaN  alvin langsford
# 2            21  2015-03-03     robby bacino
# 3             2  2013-12-09       john louis
# 4            15         NaN    ryan bergeron
# ..          ...         ...              ...
# 252           3         NaN  richard mottley
# 253           9  2010-03-01  melissa messina
# 254          12  2010-03-01    calvin prevou
# 255          16         NaN  lorine williams
# 256          20  1999-11-18     teddy torres
#
#                                                  title   fileid
# 0    AGENDA ITEM #3\nDISCUSSION: GRANT HEARING OF A...  d6f38b6
# 1    AGENDA ITEM #8\nDISCUSSION: CERTIFY TRANSCRIPT...  d6f38b6
# 2    AGENDA ITEM #4\nHEARING OF APPEAL\nFIRE DRIVER...  14ae1ba
# 3    AGENDA ITEM #3\nHEARING OF APPEAL: POLICE OFFI...  e973a89
# 4    AGENDA ITEM #4\nDISCUSSION: GRANT HEARING OF A...  3c72de3
# ..                                                 ...      ...
# 252  AGENDA ITEM #4\nHEARING: LIEUTENANT RICHARD MO...  252c64f
# 253  AGENDA ITEM #3\nHEARING OF APPEAL: Correctiona...  f0dfb3f
# 254  AGENDA ITEM #5\nDISCUSSION: GRANT HEARING OF A...  f0dfb3f
# 255  APPEAL HEARING FOR LORINE WILLIAMS (1 DAY SUSP...  5f8195c
# 256  APPEAL HEARING FOR TEDDY TORRES (3 DAY SUSPENS...  5f8195c
#
# [257 rows x 10 columns]
