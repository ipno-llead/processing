# %%
import sys; sys.path.append('../')

import pandas as pd

from clean.ponchatoula_pd import clean_cprr

# %%
import sys; sys.path.append('../')

import pandas as pd

from clean.ponchatoula_pd import clean_cprr, clean_pprr

# %%
df = clean_cprr()
df
# Out:
#       first_name  last_name receive_date  \
# 0        jeremy     ballard     9/7/2011
# 1        jeremy     ballard   10/30/2012
# 2          david     bryant    2/23/2014
# 3          david     bryant    2/24/2018
# 4          david     bryant    5/30/2018
# 5         donald     burton    3/29/2010
# 6         donald     burton    9/15/2010
# 7         donald     burton     3/9/2011
# 8         donald     burton    4/21/2011
# 9         donald     burton    6/15/2011
# 10        donald     burton   11/14/2017
# 11        donald     burton    5/30/2018
# 12         allen      bubsy    8/14/2018
# 13         allen      bubsy    2/26/2019
# 14      leander     chester     8/5/2008
# 15      leander     chester   10/16/2018
# 16      leander     chester    9/22/2019
# 17      leander     chester   10/20/2020
# 18       richard   davidson     3/7/2013
# 19       richard   davidson    6/12/2013
# 20       richard   davidson    6/27/2014
# 21       richard   davidson    2/17/2017
# ...

# %%
clean_pprr()
# Out:
#     employee_id first_name middle_initial  last_name department_desc  \
# 0         60434     jerome              l   mcdowell          police
# 1         60469      terry              j   guillory          police
# 2         60468      donna              v     fisher  communications
# 3         60494   marshall                     price          police
# 4         60444     morris                 mashon jr          police
# ..          ...        ...            ...        ...             ...
# 71        60584      frank              s     tallia          police
# 72        60520    damieon              r     tanner          police
# 73        60612    patrick                   trammel          police
# 74        60547     curtis              j   whitaker          police
# 75        60531     nicole                  williams  communications
#
#    termination_date  salary salary_freq     sex hire_year hire_month hire_day  \
# ...
