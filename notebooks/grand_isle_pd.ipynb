# %%
import sys; sys.path.append('../')
import pandas as pd

from clean.grand_isle_pd import clean

# %%
df = clean()
df
# Out:
#       last_name   first_name        rank_desc birth_year birth_month  \
# 0       barbier      anthony                        1971          11
# 1        besson        keith         sergeant       1968          10
# 2        billot       travis                        1983          12
# 3        billot       travis                        1983          12
# 4     blanchard         dale                        1979           7
# 5        dubois        euris  chief of police       1948          11
# 6       eschete        stacy          officer       1976          10
# 7       eschete        stacy          officer       1976          10
# 8    esponge jr       norris                        1963           6
# 9      francois        bruce                        1946           5
# 10     gravette        tyson                        1971          11
# 11     gravette        tyson                        1971          11
# 12         legg       joshua                        1979          11
# ...

# %%
df[df.uid == '0565fd554096ee60cf16a6eb0fde6e7f']
# Out:
# Empty DataFrame
# Columns: [last_name, first_name, rank_desc, birth_year, birth_month, birth_day, data_production_year, agency, uid, employment_status, salary, salary_freq, hire_year, hire_month, hire_day, pay_effective_year, pay_effective_month, pay_effective_day]
# Index: []

# %%
post = pd.read_csv('../data/clean/pprr_post_2020_11_06.csv')
post.loc[post.agency.str.contains('grand'), 'agency'].unique()
# Out:
# array(['grand coteau pd', 'grand isle pd', 'state parks - grand isle'],
#       dtype=object)
