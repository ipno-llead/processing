# %%
import sys; sys.path.insert(0, '../')

import pandas as pd

from clean.sterlington_csd_pprr import clean

# %%
df = clean()
df
# Out:
# standardize_from_lookup_table: unmatched sequences:
#   set()
#          rank_desc   hire_date termination_date   salary first_name  \
# 0            chief    2/2/2002         current   61000.0      barry
# 1   assitant chief  12/20/2006        5/16/2013  36000.0       todd
# 2   assitant chief   5/26/2008        6/15/2015  36000.0      jerre
# 3        patrolman   6/25/2008         2/8/2012  24000.0      kevin
# 4         sergeant   6/12/2009        5/11/2012  28000.0      jacob
# 5        patrolman   3/25/2010        11/8/2010  24000.0      randy
# 6        patrolman   4/27/2011        9/28/2011  24000.0       alex
# 7        patrolman  10/11/2011        3/30/2015  24000.0       matt
# 8         sergeant    4/4/2012       11/22/2014  30000.0     daniel
# 9        patrolman  10/23/2012        2/27/2013  24000.0     thomas
# 10        sergeant   4/25/2012         7/3/2016  36000.0      david
# 11       patrolman    3/4/2013        4/17/2013  24000.0       kyle
# ...

# %%
df[df.uid.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rank_desc, hire_date, termination_date, salary, first_name, last_name, race, sex, birth_year, birth_month, birth_day, agency, salary_freq, uid]
# Index: []
