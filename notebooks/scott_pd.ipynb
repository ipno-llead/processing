# %%
import sys; sys.path.append('../')
import pandas as pd

from clean.scott_pd_pprr import clean

# %%
df = clean()
df
# Out:
# ../clean/scott_pd_pprr.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   series = series.str.replace(pat, r"\2").str.strip()
# ../clean/scott_pd_pprr.py:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.loc[:, "rank_desc"] = df.rank_desc.str.lower().str.strip()\
#              full_name     sex   race    salary  badge_no  \
# 0           Chad Leger    male  white  89064.77     10005
# 1           Gary Nezat    male  white  76016.93     10023
# 2      Orlando Calhoun    male  black  81978.62     10031
# 3          Caleb Lege'    male  white  66978.91     10075
# 4        Larry Isadore    male  white  60529.25     10077
# 5           Juan Leger    male  white  49093.82     10105
# 6        Brun Lavergne    male  white  55967.81     10111
# 7       Hayden Godeaux    male  white  55967.81     10112
# 8        Brooks Benoit    male  white  50642.59     10113
# ...

# %%
df.full_name.str.strip().str.lower().str.extract(r'^([^ ]+) (?:([^ ]+) )?(.+)')
# Out:
#               0     1          2
# 0          chad   NaN      leger
# 1          gary   NaN      nezat
# 2       orlando   NaN    calhoun
# 3         caleb   NaN      lege'
# 4         larry   NaN    isadore
# 5          juan   NaN      leger
# 6          brun   NaN   lavergne
# 7        hayden   NaN    godeaux
# 8        brooks   NaN     benoit
# 9         colby   NaN     lantia
# 10  christopher   NaN     taylor
# 11       joseph   NaN  celestine
# 12       kevern   NaN     stoute
# 13        aaron  cody     savoie
# 14        brian   NaN   louviere
# 15      daryous   NaN   portalis
# 16       samuel   NaN    stewart
# 17       elliot   NaN  bourgeois
# 18        lance   NaN     mouton
# 19    stephanie     l     stelly
# 20      gerrett   NaN    johnson
# 21     benjamin   NaN    richard
# 22       colton   NaN  scarberry
# 23      desmond   NaN      adams
# 24      maranda   NaN     wilson
# 25      lindsey   NaN     benoit
# 26        brent   NaN     tezeno
# ...
