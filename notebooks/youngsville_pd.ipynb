# %%
import sys; sys.path.insert(0, '../')

import pandas as pd

from clean.youngsville_pd import clean_pprr_17_18, clean_pprr_19

# %%
df17 = clean_pprr_17_18('raw/youngsville_pd/youngsville_csd_pprr_2017.csv')
df17
# Out:
#       salary   hire_date          agency salary_freq first_name    last_name  \
# 0   23025.70   7/17/2017  Youngsville PD      yearly      lucas    alexander
# 1   58861.04   2/23/2015  Youngsville PD      yearly      pedro    alexander
# 2   27469.07   1/26/2015  Youngsville PD      yearly      lydia   armbruster
# 3   42974.22   1/14/2016  Youngsville PD      yearly      brian  baumgardner
# 4   37674.42   3/16/2015  Youngsville PD      yearly      louis       berges
# 5   25676.86    7/2/2009  Youngsville PD      yearly      scott      bernard
# 6   68110.57    1/1/2014  Youngsville PD      yearly    richard    boudreaux
# 7   48462.66   1/13/2013  Youngsville PD      yearly      jason        brown
# 8   15770.04   8/27/2012  Youngsville PD      yearly       chad    caruthers
# 9   67444.50   3/21/2011  Youngsville PD      yearly       john      davison
# 10  36391.48    9/5/2014  Youngsville PD      yearly      tracy       girard
# ...

# %%
df18 = clean_pprr_17_18('raw/youngsville_pd/youngsville_csd_pprr_2018.csv')
df18
# Out:
#       salary   hire_date          agency salary_freq   first_name  \
# 0   52335.60   7/17/2017  Youngsville PD      yearly        lucas
# 1   72926.11   2/23/2015  Youngsville PD      yearly        pedro
# 2   28007.76   1/26/2015  Youngsville PD      yearly        lydia
# 3   57191.36   1/14/2016  Youngsville PD      yearly        brian
# 4   39442.46   3/16/2015  Youngsville PD      yearly        louis
# 5   68110.53    1/1/2014  Youngsville PD      yearly      richard
# 6   55866.33   1/13/2013  Youngsville PD      yearly        jason
# 7   10699.15    8/7/2018  Youngsville PD      yearly        logan
# 8   73558.70   3/21/2011  Youngsville PD      yearly         john
# 9   36520.16    9/5/2014  Youngsville PD      yearly        tracy
# 10  50266.69   3/15/2012  Youngsville PD      yearly        lloyd
# 11  47755.04    2/2/2015  Youngsville PD      yearly        larry
# 12  15250.66   7/30/2018  Youngsville PD      yearly     louvenia
# ...

# %%
df19 = clean_pprr_19()
df19
# Out:
#       salary          agency salary_freq   first_name    last_name  \
# 0   42920.68  Youngsville PD      yearly        lucas    alexander
# 1   68514.13  Youngsville PD      yearly        pedro    alexander
# 2   31383.35  Youngsville PD      yearly        james       ardoin
# 3   23594.45  Youngsville PD      yearly        lydia   armbruster
# 4   55333.62  Youngsville PD      yearly        brian  baumgardner
# 5   13760.65  Youngsville PD      yearly         neal     bergeron
# 6   34104.30  Youngsville PD      yearly        louis       berges
# 7   63461.56  Youngsville PD      yearly      richard    boudreaux
# 8   42038.51  Youngsville PD      yearly        jason        brown
# 9   13552.28  Youngsville PD      yearly       devlin       cabean
# 10  65467.80  Youngsville PD      yearly         john      davison
# 11   9663.47  Youngsville PD      yearly       hilary        fruge
# 12  42615.54  Youngsville PD      yearly         tony      galyean
# ...

# %%
df19.first_name[df19.first_name.str.len() == df19.first_name.str.len().max()].iloc[0]
# Out:
# 'christopher'
