# %%
import sys; sys.path.append("../")
import pandas as pd

# %%
per = pd.read_csv('../data/fuse/personnel.csv')
com = pd.read_csv('../data/fuse/complaint.csv')
event = pd.read_csv('../data/fuse/event.csv')
uof = pd.read_csv('../data/fuse/use_of_force.csv')
# Out:
# /Users/khoipham/.virtualenvs/base/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (3,4,9,17,18,20,24,25,32,39,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/khoipham/.virtualenvs/base/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (9,10,12,13,14,16,17,18,19,20,24,25,26,29,30,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import sys; sys.path.append('../')

import pandas as pd

# %%
per = pd.read_csv('../data/fuse/personnel.csv')
per
# Out:
#                                     uid last_name middle_name middle_initial  \
# 0      000526fa05739e97b61343513a92dbc7     St Pe         NaN              E
# 1      00053b0fb61b7ddd8d3f6c55bdcf6a53   Bentley         NaN            NaN
# 2      0005624eee7c188d3604f2294dfb195d   Sanchez           C              C
# 3      0007884f101d1661937abb130664d2d2   Coleman         NaN            NaN
# 4      0007f3f6802b9fa493622d4a23edc00b   Chapman       Wayne              W
# ...                                 ...       ...         ...            ...
# 19647  ffe742161e9ec8ce7d646806e14a0981     Hicks         NaN            NaN
# 19648  ffec62d1194c7005a56c227c3b8d8562   Sunseri           S              S
# 19649  ffed8bba5b654be261b1eee71ebf01f4    Youngs         NaN            NaN
# 19650  fff0140215ef8b53a661750445758776   Thaxton         NaN            NaN
# 19651  fff26ff85cbd01722b9da1ceca1fd350     Robin         NaN            NaN
#
#       first_name  birth_year  birth_month  birth_day   race   sex
# 0         Cheryl         NaN          NaN        NaN    NaN   NaN
# 1        Stephen         NaN          NaN        NaN    NaN   NaN
# 2          Emile         NaN          NaN        NaN    NaN  male
# 3           John         NaN          NaN        NaN    NaN   NaN
# 4           Ryan         NaN          NaN        NaN    NaN   NaN
# ...          ...         ...          ...        ...    ...   ...
# 19647      Wendy      1955.0          NaN        NaN    NaN   NaN
# 19648     Lucian      1941.0          NaN        NaN  white  male
# 19649    Michael         NaN          NaN        NaN    NaN   NaN
# 19650      Jimmy         NaN          NaN        NaN    NaN   NaN
# 19651      Donny         NaN          NaN        NaN    NaN   NaN
#
# [19652 rows x 10 columns]

# %%
uids = per.loc[per.race == 'w', 'uid'].to_list()

# %%
ev = pd.read_csv('../data/fuse/event.csv')
ev
# Out:
# /Users/khoipham/.virtualenvs/base/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (5,9,10,12,13,14,16,17,18,19,20,24,25,26,29,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                event_uid                         kind  year  \
# 0       000a481fd9a05f87218458bd00c65a8d                 officer_dept  2013
# 1       001cbb9af554552273bad1a6082acec1        officer_pay_effective  2011
# 2       00264646f885f9ffcb9bee2d7c7cdd80                 officer_dept  2018
# 3       00291fd311feeed77f10659468c6ca4c        officer_pay_effective  2019
# 4       002add77d35f58244041315df9322b20                 officer_rank  2013
# ...                                  ...                          ...   ...
# 155856  fea2d292e431fa6fa4fb878d898c4593  officer_pc_12_qualification  2019
# 155857  fea8b6a044cf76f74ed7888460b5d7f7         officer_level_1_cert  2007
# 155858  feccd2a8b7a5edb95f6d330a919a69c1  officer_pc_12_qualification  2020
# 155859  ff9e194f14b3894c04938cbfdee0eec4  officer_pc_12_qualification  2016
# 155860  fff0aca61fb5f696a305200a3fe03a0d                 officer_hire  2008
#
#         month   day time    raw_date                               uid  \
# 0         NaN   NaN  NaN         NaN  6d82e73c3d401a0424eef198d7ace669
# 1         NaN   NaN  NaN         NaN  3197945e273d79968f5da84b440796d1
# 2         NaN   NaN  NaN         NaN  ede3c72ebc58c47f15336060c61dddf8
# 3         NaN   NaN  NaN         NaN  306feb7a91b30f5681c871e9095cbaf1
# 4         NaN   NaN  NaN         NaN  6b9809c17fab75e8992ff82fad0cbdc3
# ...       ...   ...  ...         ...                               ...
# 155856    6.0   5.0  NaN  2019-06-05  dc6663b725af10ac368a6472ede8ea17
# 155857   10.0  18.0  NaN  2007-10-18  cd72fde1489475fdeda920bda8fe94e3
# 155858   10.0  21.0  NaN  2020-10-21  20d1f2c1fecdbbfb8a42a901a034a729
# 155859   10.0  21.0  NaN  2016-10-21  f299c69735c1aa27ff24313b1de37dcf
# 155860    6.0   8.0  NaN         NaN  c07070ef131c23861efbdf24df7026dc
#
#        complaint_uid appeal_uid  ... employment_status sworn officer_inactive  \
# 0                NaN        NaN  ...               NaN   NaN              NaN
# 1                NaN        NaN  ...               NaN   NaN              NaN
# 2                NaN        NaN  ...               NaN   NaN              NaN
# 3                NaN        NaN  ...               NaN   NaN              NaN
# 4                NaN        NaN  ...               NaN   NaN              NaN
# ...              ...        ...  ...               ...   ...              ...
# 155856           NaN        NaN  ...         full-time   NaN              NaN
# 155857           NaN        NaN  ...         full-time   NaN              NaN
# 155858           NaN        NaN  ...         full-time   NaN              NaN
# 155859           NaN        NaN  ...         full-time   NaN              NaN
# 155860           NaN        NaN  ...         full-time   NaN              NaN
#
#        employee_type years_employed    salary salary_freq award  \
# 0                NaN            NaN       NaN         NaN   NaN
# 1                NaN            NaN  10262.14      yearly   NaN
# 2                NaN            NaN       NaN         NaN   NaN
# 3                NaN            NaN  62373.35      yearly   NaN
# 4                NaN            NaN       NaN         NaN   NaN
# ...              ...            ...       ...         ...   ...
# 155856           NaN            NaN       NaN         NaN   NaN
# 155857           NaN            NaN       NaN         NaN   NaN
# 155858           NaN            NaN       NaN         NaN   NaN
# 155859           NaN            NaN       NaN         NaN   NaN
# 155860           NaN            NaN       NaN         NaN   NaN
#
#        award_comments left_reason
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# ...               ...         ...
# 155856            NaN         NaN
# 155857            NaN         NaN
# 155858            NaN         NaN
# 155859            NaN         NaN
# 155860            NaN         NaN
#
# [155861 rows x 33 columns]

# %%
ev.loc[ev.year > 2021, ['agency', 'kind']]
# Out:
#                 agency                    kind
# 46280   New Orleans PD      complaint_incident
# 49014   New Orleans PD      complaint_incident
# 53750   New Orleans PD      complaint_incident
# 57155   New Orleans PD      complaint_incident
# 66008   New Orleans PD      complaint_incident
# 83691   New Orleans PD      complaint_incident
# 85132   New Orleans PD      complaint_incident
# 88915   New Orleans PD      complaint_incident
# 90875   New Orleans PD      complaint_incident
# 92928   New Orleans PD      complaint_incident
# 108520  New Orleans PD      complaint_incident
# 111170  New Orleans PD      complaint_incident
# 112868  New Orleans PD      complaint_incident
# 130233  New Orleans PD      complaint_incident
# 133500  New Orleans PD      complaint_incident
# 150553   Tangipahoa SO  investigation_complete
