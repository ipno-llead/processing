# %%
import sys; sys.path.insert(0, '../')

import pandas as pd

from clean.west_monroe_pd_pprr import clean

# %%
df = clean()
df
# Out:
# standardize_from_lookup_table: unmatched sequences:
#   set()
#    rank_desc  badge   race     sex   hire_date   salary first_name  last_name  \
# 0    captain   95.0  white    male  07/16/1992  4046.24       gary   aldridge
# 1    officer  208.0  white    male  04/06/2006  2882.49       john      allen
# 2    officer  197.0  white    male  10/13/2008  2977.38     reggie      allen
# 3    officer  252.0  white    male  09/21/2009  2831.83      james      baker
# 4   corporal  166.0  white    male  08/16/2001  3259.60    charles       beck
# ..       ...    ...    ...     ...         ...      ...        ...        ...
# 68  corporal  167.0  white    male  10/15/2001  3011.92    michael      tully
# 69   captain  102.0  black    male  05/24/1993  4002.80       carl     turner
# 70  corporal  163.0  white  female  03/01/2001  2838.16       gina     walker
# 71   officer  267.0  white  female  09/23/2010  2660.83      amber      white
# ...

# %%
df[df.uid.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rank_desc, badge, race, sex, hire_date, salary, first_name, last_name, agency, salary_freq, uid]
# Index: []
