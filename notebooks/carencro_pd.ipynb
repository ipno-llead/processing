# %%
import sys; sys.path.insert(0, '../')

import pandas as pd

from clean.carencro_pd_pprr import clean

# %%
df = clean()
df
# Out:
# standardize_from_lookup_table: unmatched sequences:
#   set()
# standardize_from_lookup_table: unmatched sequences:
#   set()
#        last_name first_name           rank_desc                 dept_desc  \
# 0       anderson      david               chief                       NaN
# 1        richard     ronnie     assistant chief                       NaN
# 2         walker      trent            sergeant                   command
# 3         walker  toby-dean           detective            investigations
# 4          istre      tyler           detective            investigations
# 5       mitchell      jamie             officer  school resource officers
# 6          geans      jason             officer  school resource officers
# 7   vanasselberg      derek             officer  school resource officers
# 8       primeaux       chad             officer  school resource officers
# 9         trahan       troy             officer          special services
# ...

# %%
df.rank_desc.unique()
# Out:
# array(['chief', 'assistant chief', 'sergeant', 'detective', 'officer',
#        'military/activated', 'captain'], dtype=object)
