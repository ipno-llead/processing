# %%
import sys; sys.path.append("../")
import pandas as pd

from clean.ipm_new_orleans_iapro_pprr import clean
from fuse.new_orleans_pd import fuse_events
from lib.columns import clean_column_names
from lib.explore import show_unique
from lib.uid import gen_uid
from lib import events

# %%
df = clean()
df
# Out:
#      employee_id badge_no              rank_desc     employee_type  \
# 0            368      NaN     complaint operator  non-commissioned
# 1           6353      NaN    performance auditor  non-commissioned
# 2           4092      NaN  school crossing guard  non-commissioned
# 3           3318      340               sergeant      commissioned
# 4           4093      NaN  school crossing guard  non-commissioned
# ...          ...      ...                    ...               ...
# 5665        5813      NaN                                      NaN
# 5666        5859      NaN                                      NaN
# 5667        6014      NaN                                      NaN
# 5668        5265      NaN                                      NaN
# 5669        5350      NaN                                      NaN
#
#      employment_status officer_inactive years_employed birth_year     sex  \
# 0           terminated              yes             14       1984  female
# 1               active               no              4       1986  female
# 2           terminated              yes             23       1941  female
# 3              retired              yes             39       1943  female
# 4           terminated              yes             25       1977  female
# ...                ...              ...            ...        ...     ...
# 5665                                 no
# 5666                                 no
# 5667                                 no
# 5668          inactive              yes
# 5669          inactive              yes
#
#                           race  ... hire_year hire_month hire_day left_year  \
# 0     Black / African American  ...      2007          3       18
# 1     Black / African American  ...      2017          8        6
# 2     Black / African American  ...      1998         11       22      2005
# 3                        White  ...      1982          8       29      2006
# 4     Black / African American  ...      1996         11       14      1997
# ...                        ...  ...       ...        ...      ...       ...
# 5665              Unknown race  ...
# 5666              Unknown race  ...
# 5667              Unknown race  ...
# 5668              Unknown race  ...
# 5669              Unknown race  ...
#
#      left_month left_day dept_year dept_month dept_day middle_initial
# 0                             2014          3       23
# 1                             2017          8        7              s
# 2            10       14      2005         10       14              l
# 3             7        9      2006          7        9              r
# 4             2       21      1999          3       28              n
# ...         ...      ...       ...        ...      ...            ...
# 5665
# 5666
# 5667
# 5668
# 5669
#
# [5670 rows x 31 columns]

# %%
df.race.unique()
# Out:
# array(['Black / African American', 'White', 'Native American', 'Hispanic',
#        'Asian / Pacific Islander', 'Unknown race'], dtype=object)
