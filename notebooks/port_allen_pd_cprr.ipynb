# %%
import sys; sys.path.append("../")

import pandas as pd

from clean.port_allen_pd_cprr import clean19

# %%
df = clean19()
df
# Out:
#    date_filed rank_desc first_name last_name badge_no  \
# 0     1/24/19   officer      craig  crawford  PA-28\n
# 1     6/18/19   officer       eric   reineke  PA-11\n
# 2     6/20/19   officer      craig  crawford  PA-28\n
# 3     6/21/19  corporal      bobby    hopson   PA-8\n
# 4     6/25/19  corporal      bobby    hopson   PA-8\n
# 5      7/8/19   officer       eric   reineke  PA-11\n
# 6      6/7/19   officer      craig  crawford  PA-28\n
# 7     7/16/19   officer      craig  crawford  PA-28\n
# 8     8/19/19  corporal      bobby    hopson   PA-8\n
# 9     8/15/19   officer      craig  crawford  PA-28\n
# 10    9/19/19   officer       jana    chustz  PA-13\n
# 11    1/28/19   officer      craig  crawford  PA-28\n
# 12    8/28/19   officer       eric   reineke  PA-11\n
# 13   10/14/19   officer    latrese    darden   PA-6\n
# 14   11/23/19   officer      craig  crawford  PA-28\n
# 15   12/16/19   officer      craig  crawford  PA-28\n
# ...

# %%
violations = df.charge.str.split("#", expand=True)
violations.drop(columns=[0])
# Out:
#                                                     1  \
# 0               2:15 Conduct Unbecoming of an Officer
# 1                            112/2: Command of Temper
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# 5        2:15 Conduct Unbecoming An Officer (Pending)
# 6                            3:11 Carrying Out Orders
# 7               2:15 Conduer Unbecoming of an Officer
# 8               2:15 Conduct Unbecoming of an Officer
# 9               2:15 Conduer Unbecoming of an Officer
# 10                Departmental Motor Vehicle Accident
# 11                  122 Departmental Vehicle Accident
# 12              2:15 Conduct Unbecoming of an Officer
# 13                  122 Departmental Vehicle Accident
# 14  123 Departmental Motor Vehicle Accident (Not a...
# 15                                                N/A
# ...
