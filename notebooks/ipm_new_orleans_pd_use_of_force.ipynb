# %%
import sys; sys.path.append('../')
import pandas as pd

from clean.ipm_new_orleans_pd_use_of_force import clean
from lib.explore import show_unique

# %%
df = clean()
df
# Out:
# ../clean/ipm_new_orleans_pd_use_of_force.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.loc[:, col] = df[col].str.replace(r' \d:\d\d$', '')
# ../clean/ipm_new_orleans_pd_use_of_force.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.loc[:, 'occur_day'] = df.occur_date.str.replace(
# ../clean/ipm_new_orleans_pd_use_of_force.py:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.occur_minute.str.replace(r'\:.+', ''), sep=':')
#      uof_tracking_number  report_year  occur_year  occur_month  \
# 0           FTN2019-0054         2019        2019            2
# 1           FTN2019-0054         2019        2019            2
# 2           FTN2019-0046         2019        2019            2
# 3           FTN2019-0046         2019        2019            2
# 4           FTN2019-0047         2019        2019            2
# ...                  ...          ...         ...          ...
# 4907        FTN2016-0549         2016        2015           11
# 4908        FTN2016-0549         2016        2015           11
# 4909        FTN2016-0644         2016        2012           12
# 4910        FTN2016-0644         2016        2012           12
# 4911        FTN2016-0644         2016        2012           12
#
#      officer_primary_key citizen_primary_key        force_description  \
# 0                   1455               13857   L2-Takedown (w/injury)
# 1                   6080               13857   L2-Takedown (w/injury)
# 2                   6150               13840  L1-Takedown (no injury)
# 3                   6127               13840  L1-Takedown (no injury)
# 4                    731               13842  L3-Baton/PR-24 (Strike)
# ...                  ...                 ...                      ...
# 4907                5904               10747   L1-Force (Escort Tech)
# 4908                5905               10747   L1-Force (Escort Tech)
# 4909                5956               10955   L1-No Force by Officer
# 4910                3555               10955   L1-Firearm (Exhibited)
# 4911                2251               10955   L1-CEW Exhibited/Laser
#
#                 force_type force_level effective_uof  ...  \
# 0      Takedown (w/injury)          L2           yes  ...
# 1      Takedown (w/injury)          L2           yes  ...
# 2     Takedown (no injury)          L1           yes  ...
# 3     Takedown (no injury)          L1           yes  ...
# 4     Baton/PR-24 (Strike)          L3            no  ...
# ...                    ...         ...           ...  ...
# 4907   Hands / Escort tech          L1           yes  ...
# 4908   Hands / Escort tech          L1           yes  ...
# 4909   No Force by Officer          L1           yes  ...
# 4910     Firearm Exhibited          L1           yes  ...
# 4911       Taser Exhibited          L1           yes  ...
#
#      officer_employment_status               officer_department  \
# 0                       active    FOB - Field Operations Bureau
# 1                       active    FOB - Field Operations Bureau
# 2                       active    FOB - Field Operations Bureau
# 3                       active    FOB - Field Operations Bureau
# 4                       active    FOB - Field Operations Bureau
# ...                        ...                              ...
# 4907                    active    FOB - Field Operations Bureau
# 4908                    active    FOB - Field Operations Bureau
# 4909                terminated    FOB - Field Operations Bureau
# 4910                    active  MSB - Management Service Bureau
# 4911                    active  MSB - Management Service Bureau
#
#                     officer_division officer_sub_division_a  \
# 0                                NaN                    NaN
# 1                     Third District              B Platoon
# 2                                NaN                    NaN
# 3                     Third District              C Platoon
# 4                    Eighth District              A Platoon
# ...                              ...                    ...
# 4907                  First District            1st Platoon
# 4908                  First District            1st Platoon
# 4909                Seventh District            Night Watch
# 4910  Administrative Duties Services                   LWOP
# 4911  Administrative Duties Services  Workmans Compensation
#
#      officer_sub_division_b occur_day occur_time data_production_year  \
# 0                       NaN        12      12:37                 2019
# 1                       NaN        12      12:37                 2019
# 2                       NaN         6      12:59                 2019
# 3                       NaN         6      12:59                 2019
# 4                       NaN         6      12:52                 2019
# ...                     ...       ...        ...                  ...
# 4907                    NaN         5      17:50                 2019
# 4908                    NaN         5      17:50                 2019
# 4909                    NaN        26      03:07                 2019
# 4910                    NaN        26      03:07                 2019
# 4911                    NaN        26      03:07                 2019
#
#               agency                           uof_uid
# 0     New Orleans PD  ffabb4817d214d093ab033d75e81f0bd
# 1     New Orleans PD  17422a3c552cb5a25e0242edf7cc3b7c
# 2     New Orleans PD  3bb401f7ccf70e2aa6d1765f1ac08ed5
# 3     New Orleans PD  cc31d83fe0cc8bc074ee968fde1d9e39
# 4     New Orleans PD  c422a0987afabce2e27190152da7650c
# ...              ...                               ...
# 4907  New Orleans PD  c15d6121598cd79fee3769ed4574a870
# 4908  New Orleans PD  cc9cd2b2b8b3ceddb41f61266dba8606
# 4909  New Orleans PD  d74fc1fd1cd8731ca56562b1577a8839
# 4910  New Orleans PD  900a288ad2f34c9a4fe7a32b421b2f67
# 4911  New Orleans PD  3ed81f1836ca1dc7d998f278497d147c
#
# [4886 rows x 56 columns]

# %%
df[df.uof_tracking_number == 'FTN2017-0285']
# Out:
#      uof_tracking_number  report_year  occur_year  occur_month  \
# 2290        FTN2017-0285         2017        2017            6
# 2291        FTN2017-0285         2017        2017            6
# 2292        FTN2017-0285         2017        2017            6
# 2293        FTN2017-0285         2017        2017            6
# 2294        FTN2017-0285         2017        2017            6
# 2295        FTN2017-0285         2017        2017            6
# 2296        FTN2017-0285         2017        2017            6
# 2297        FTN2017-0285         2017        2017            6
#
#      officer_primary_key citizen_primary_key       force_description  \
# 2290                1531               11681  L1-Firearm (Exhibited)
# 2291                1531               11682  L1-Firearm (Exhibited)
# 2292                1531               11683  L1-Firearm (Exhibited)
# 2293                1531               11684  L1-Firearm (Exhibited)
# 2294                1663               11684  L1-Firearm (Exhibited)
# 2295                1663               11683  L1-Firearm (Exhibited)
# 2296                1663               11682  L1-Firearm (Exhibited)
# 2297                1663               11681  L1-Firearm (Exhibited)
#
#              force_type force_level effective_uof  ...  \
# 2290  Firearm Exhibited          L1           yes  ...
# 2291  Firearm Exhibited          L1           yes  ...
# 2292  Firearm Exhibited          L1           yes  ...
# 2293  Firearm Exhibited          L1           yes  ...
# 2294  Firearm Exhibited          L1            no  ...
# 2295  Firearm Exhibited          L1            no  ...
# 2296  Firearm Exhibited          L1            no  ...
# 2297  Firearm Exhibited          L1            no  ...
#
#      officer_employment_status             officer_department  \
# 2290                    active  FOB - Field Operations Bureau
# 2291                    active  FOB - Field Operations Bureau
# 2292                    active  FOB - Field Operations Bureau
# 2293                    active  FOB - Field Operations Bureau
# 2294                    active  FOB - Field Operations Bureau
# 2295                    active  FOB - Field Operations Bureau
# 2296                    active  FOB - Field Operations Bureau
# 2297                    active  FOB - Field Operations Bureau
#
#      officer_division officer_sub_division_a officer_sub_division_b occur_day  \
# 2290  Fourth District             Task Force                      A         5
# 2291  Fourth District             Task Force                      A         5
# 2292  Fourth District             Task Force                      A         5
# 2293  Fourth District             Task Force                      A         5
# 2294   Third District              B Platoon                    NaN         5
# 2295   Third District              B Platoon                    NaN         5
# 2296   Third District              B Platoon                    NaN         5
# 2297   Third District              B Platoon                    NaN         5
#
#      occur_time data_production_year          agency  \
# 2290      23:58                 2019  New Orleans PD
# 2291      23:58                 2019  New Orleans PD
# 2292      23:58                 2019  New Orleans PD
# 2293      23:58                 2019  New Orleans PD
# 2294      23:58                 2019  New Orleans PD
# 2295      23:58                 2019  New Orleans PD
# 2296      23:58                 2019  New Orleans PD
# 2297      23:58                 2019  New Orleans PD
#
#                                uof_uid
# 2290  7acfe17de8605d9142b1a8e76d9c4bc7
# 2291  3dc4de44d195e15c0820623996fb1d1d
# 2292  3caf6c7f282a3fab4e9b84550ded7f13
# 2293  393092c8d39b474b6461051f389442cf
# 2294  702eeb15380ebbd9a8f6949c9fddaa7f
# 2295  f6d5d2501366b0e663d5e6def93cfb08
# 2296  0974675381c9d5622fd118ed0aa3ba9d
# 2297  02cd84f72faa37eaf7cd9da3bc5e5519
#
# [8 rows x 56 columns]
