# %%
import sys
sys.path.append('../')
import pandas as pd
from lib.path import data_file_path
from lib.columns import clean_column_names


def review_first_names_from_post_20():
    df = pd.read_excel('C:/Users/ayyubi/llead/processing/data/match/lake_charles_pd_cprr_2020_assign_first_name_from_post_pprr_2020_11_06.xlsx', sheet_name='All pairs')
    df = df\
        .pipe(clean_column_names)
    return df

# %%
df = review_first_names_from_post_20()
df
# Out:
#     pair_idx  sim_score                           row_key first_name  \
# 0        0.0   1.000000  626527ddb03134ab13301b47e02789f4      bendy
# 1        NaN        NaN  6789cb26c30c1b5d6fee2062de4d9a63      bendy
# 2        1.0   1.000000  02287aa2ae8a6ffeff67ae32bd7eb7fe    raymond
# 3        NaN        NaN  bbf642acb1085eb6bf7dfa77ba28e543    raymond
# 4        2.0   1.000000  21b9fee875deea6aecb027774f46eb77    carlton
# 5        NaN        NaN  9e0a78c3bf8f05a6de7e7cfdce7a968b    carlton
# 6        3.0   1.000000  eb9b628338da23105ad816106b8abc38     joshua
# 7        NaN        NaN  c9793d0ab4c76d27416175cf508d5c3b     joshua
# 8        4.0   1.000000  c09341a2fbb0a03e9b09ca9c39ed3b5f      errel
# 9        NaN        NaN  df89acc556d766c10a0cbbcadea0276c      errel
# 10       5.0   1.000000  8a6e464c06eceecb034d678c145c7b37      logan
# 11       NaN        NaN  032b77194510f1f177945c919ba196ad      logan
# 12       6.0   1.000000  7e670d03553e829c0beb17d0aab280fd     hannah
# ...

# %%
def review_first_names_from_post_19():
    df = pd.read_excel('C:/Users/ayyubi/llead/processing/data/match/lake_charles_pd_cprr_2014_2019_assign_first_name_from_post_pprr_2020_11_06.xlsx', sheet_name='All pairs')
    df = df\
        .pipe(clean_column_names)
    return df

# %%
df = review_first_names_from_post_19()
df
# Out:
#      pair_idx  sim_score                           row_key first_name  \
# 0         0.0        1.0  492956a413106f358f2e1278d8769dd8   jonathan
# 1         NaN        NaN  7a20c6aae22d8fcb8a4dfea007a4ce84   jonathan
# 2         1.0        1.0  c70927b44f6ef76303c86fce0051239d       ryan
# 3         NaN        NaN  1a10e6182c0fddc92e62ebbd2206451d       john
# 4         2.0        1.0  be7d1961fb9ae2f5103ded752ba2a246    phillip
# ..        ...        ...                               ...        ...
# 199       NaN        NaN  cdaa3726bc8b83ad2ea8f1942b60924f     cyanna
# 200     100.0        0.7  1a4b85fd7dfe746e737e39d66ad9f2a3          j
# 201       NaN        NaN  1e72c4652f6d4832c800bc72c16e5475        ted
# 202     101.0        0.7  1105f744870ec2963d9f1b5ddb0fd3ee          c
# 203       NaN        NaN  07e8f5b9d027274198ada84e6c8e60b2    jeffrey
#
#     last_name fc
# 0     landrum  l
# 1     landrum  l
# 2     gaspard  g
# 3     gaspard  g
# 4    gardiner  g
# ...
