# %%
import sys; sys.path.append('../')
import pandas as pd

from clean.lake_charles_pd_cprr import clean_19, clean_20

# %%
df = clean_19()
df.head
# Out:
# standardize_from_lookup_table: unmatched sequences:
#   {'', 'study', '/(cets)', 's', ' ', ' of ', '-', 'y'}
# standardize_from_lookup_table: unmatched sequences:
# ...

# %%
df = clean_20()
df.head
# Out:
# <bound method NDFrame.head of       disposition investigation_start_date                      charges  \
# 0                                1/21/2020   unsatisfactory performance
# 1                                1/21/2020   unsatisfactory performance
# 2       sustained                2/26/2020   unsatisfactory performance
# 3       sustained                2/26/2020   unsatisfactory performance
# 4       unfounded                2/26/2020               abuse of power
# 5       unfounded                2/26/2020           conduct unbecoming
# 6       unfounded                 3/9/2020   unsatisfactory performance
# 7       unfounded                 3/9/2020              neglect of duty
# 8                                 3/9/2020              neglect of duty
# 9                                 3/9/2020           conduct unbecoming
# 10                               3/20/2020             false statements
# 11      sustained                4/24/2020              neglect of duty
# ...
