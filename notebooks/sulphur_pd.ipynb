# %%
import sys; sys.path.insert(0, '../')

import pandas as pd

from clean.sulphur_pd_pprr import clean

# %%
df = clean()
df
# Out:
#    employee_id officer_inactive first_name middle_initial  last_name  class  \
# 0        60434              yes     jerome              l   mcdowell   10.0
# 1        60469              yes      terry              j   guillory   10.0
# 2        60468              yes      donna              v     fisher   10.0
# 3        60494              yes   marshall                     price   10.0
# 4        60444              yes     morris                 mashon jr   10.0
# ..         ...              ...        ...            ...        ...    ...
# 71       60584               no      frank              s     tallia   10.0
# 72       60520               no    damieon              r     tanner   10.0
# 73       60612               no    patrick                   trammel   10.0
# 74       60547               no     curtis              j   whitaker   10.0
# 75       60531               no     nicole                  williams   10.0
#
# ...

# %%
df[['salary', 'salary_freq']].iloc[60:]
# Out:
#     salary salary_freq
# 60   25.82      hourly
# 61   15.50      hourly
# 62   15.92      hourly
# 63   15.00      hourly
# 64   19.58      hourly
# 65   21.45      hourly
# 66   15.09      hourly
# 67   18.36      hourly
# 68   18.69      hourly
# 69   15.86      hourly
# 70    7.50      hourly
# 71   13.74      hourly
# 72   17.63      hourly
# 73   14.49      hourly
# 74   15.70      hourly
# 75   14.66      hourly
